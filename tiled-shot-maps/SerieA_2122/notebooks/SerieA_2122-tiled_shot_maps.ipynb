# %% [markdown]
# ## **Tiled Shot Maps**

# %% [markdown]
# _Serie A 2021/22 - Matchday 1-7_

# %%
# imports
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patheffects as path_effects
import matplotlib.font_manager as fm
import matplotlib.colors as mcolors
from matplotlib import cm
from highlight_text import fig_text, ax_text
import matplotlib.gridspec as gridspec

from mplsoccer import VerticalPitch

from PIL import Image
import urllib
import os

# %% [markdown]
# **Data Preparation**

# %%
df_raw = pd.read_csv('../data/raw/07-serieA.csv', encoding='ISO-8859-1', index_col=0)
df_raw.head()
# Out:
#    match_id  match_round  league_id league_name league_round_name
# 1   3919071            1         55     Serie A   Serie A Round 1  \
# 2   3919071            1         55     Serie A   Serie A Round 1
# 3   3919071            1         55     Serie A   Serie A Round 1
# 4   3919071            1         55     Serie A   Serie A Round 1
# 5   3919071            1         55     Serie A   Serie A Round 1
#
#    parent_league_id parent_league_season                match_time_utc
# 1                55            2022/2023  Sat, Aug 13, 2022, 16:30 UTC  \
# 2                55            2022/2023  Sat, Aug 13, 2022, 16:30 UTC
# 3                55            2022/2023  Sat, Aug 13, 2022, 16:30 UTC
# 4                55            2022/2023  Sat, Aug 13, 2022, 16:30 UTC
# 5                55            2022/2023  Sat, Aug 13, 2022, 16:30 UTC
#
#    home_team_id home_team  ...  shot_type    situation     period is_own_goal
# 1          8564     Milan  ...     Header   FromCorner  FirstHalf       False  \
# 2          8564     Milan  ...  RightFoot  RegularPlay  FirstHalf       False
# 3          8564     Milan  ...   LeftFoot      Penalty  FirstHalf       False
# 4          8564     Milan  ...  RightFoot  RegularPlay  FirstHalf       False
# 5          8564     Milan  ...   LeftFoot  RegularPlay  FirstHalf       False
#
#    on_goal_shot_x on_goal_shot_y  on_goal_shot_zoom_ratio  first_name
# 1        0.939484       0.054358                 1.000000     Rodrigo  \
# 2        0.919312       0.107018                 1.000000      Brahim
# 3        0.354497       0.300668                 1.000000        Theo
# 4        0.919312       0.086633                 1.000000        Ante
# 5        0.721637       0.677249                 0.353834      Rafael
#
#    last_name  team_color
# 1      Becao     #907850
# 2       Diaz     #302028
# 3  Hernández     #302028
# 4      Rebic     #302028
# 5       Leao     #302028
#
# [5 rows x 41 columns]

# %%
df_raw.columns
# Out:
# Index(['match_id', 'match_round', 'league_id', 'league_name',
#        'league_round_name', 'parent_league_id', 'parent_league_season',
#        'match_time_utc', 'home_team_id', 'home_team', 'home_team_color',
#        'away_team_id', 'away_team', 'away_team_color', 'id', 'event_type',
#        'team_id', 'player_id', 'player_name', 'x', 'y', 'min', 'min_added',
#        'is_blocked', 'is_on_target', 'blocked_x', 'blocked_y',
#        'goal_crossed_y', 'goal_crossed_z', 'expected_goals',
#        'expected_goals_on_target', 'shot_type', 'situation', 'period',
#        'is_own_goal', 'on_goal_shot_x', 'on_goal_shot_y',
#        'on_goal_shot_zoom_ratio', 'first_name', 'last_name', 'team_color'],
#       dtype='object')

# %%
# keep only relevant columns
df_raw = df_raw[['team_id', 'player_id', 'player_name', 'min', 'expected_goals', 'event_type', 'team_color', 'match_id', 'is_own_goal', 'x', 'y', 'shot_type', 'situation']]

# %%
df_raw.head()
# Out:
#    team_id  player_id     player_name  min  expected_goals    event_type
# 1     8600     844504   Rodrigo Becao    2        0.086003          Goal  \
# 2     8564     750027     Brahim Diaz    7        0.054140  AttemptSaved
# 3     8564     724371  Theo Hernández   11        0.788400          Goal
# 4     8564     265725      Ante Rebic   15        0.075055          Goal
# 5     8564     848844     Rafael Leao   18        0.033549          Miss
#
#   team_color  match_id  is_own_goal           x          y  shot_type
# 1    #907850   3919071        False  102.344825  39.545001     Header  \
# 2    #302028   3919071        False   95.350879  19.304968  RightFoot
# 3    #302028   3919071        False   94.000000  34.000000   LeftFoot
# 4    #302028   3919071        False   94.000000  32.017501  RightFoot
# 5    #302028   3919071        False   78.768443  43.300128   LeftFoot
#
#      situation
# 1   FromCorner
# 2  RegularPlay
# 3      Penalty
# 4  RegularPlay
# 5  RegularPlay

# %%
teams_id = {8524: 'Atalanta', 9857: 'Bologna', 7801: 'Cremonese', 8534: 'Empoli', 8535: 'Fiorentina',
            8636: 'Inter', 9885: 'Juventus', 8543: 'Lazio', 9888: 'Lecce', 8564: 'Milan',
            6504: 'Monza', 9875: 'Napoli', 8686: 'Roma', 6480: 'Salernitana', 9882: 'Sampdoria',
            7943: 'Sassuolo', 9881: 'Spezia', 9804: 'Torino', 8600: 'Udinese', 9876: 'Hellas Verona'}

# %%
df_raw['team_name'] = df_raw['team_id'] 
df_raw.head()
# Out:
#    team_id  player_id     player_name  min  expected_goals    event_type
# 1     8600     844504   Rodrigo Becao    2        0.086003          Goal  \
# 2     8564     750027     Brahim Diaz    7        0.054140  AttemptSaved
# 3     8564     724371  Theo Hernández   11        0.788400          Goal
# 4     8564     265725      Ante Rebic   15        0.075055          Goal
# 5     8564     848844     Rafael Leao   18        0.033549          Miss
#
#   team_color  match_id  is_own_goal           x          y  shot_type
# 1    #907850   3919071        False  102.344825  39.545001     Header  \
# 2    #302028   3919071        False   95.350879  19.304968  RightFoot
# 3    #302028   3919071        False   94.000000  34.000000   LeftFoot
# 4    #302028   3919071        False   94.000000  32.017501  RightFoot
# 5    #302028   3919071        False   78.768443  43.300128   LeftFoot
#
#      situation  team_name
# 1   FromCorner       8600
# 2  RegularPlay       8564
# 3      Penalty       8564
# 4  RegularPlay       8564
# 5  RegularPlay       8564

# %%
df_raw[['team_name']] = df_raw[['team_name']].replace(teams_id)
df_raw.head()
# Out:
#    team_id  player_id     player_name  min  expected_goals    event_type
# 1     8600     844504   Rodrigo Becao    2        0.086003          Goal  \
# 2     8564     750027     Brahim Diaz    7        0.054140  AttemptSaved
# 3     8564     724371  Theo Hernández   11        0.788400          Goal
# 4     8564     265725      Ante Rebic   15        0.075055          Goal
# 5     8564     848844     Rafael Leao   18        0.033549          Miss
#
#   team_color  match_id  is_own_goal           x          y  shot_type
# 1    #907850   3919071        False  102.344825  39.545001     Header  \
# 2    #302028   3919071        False   95.350879  19.304968  RightFoot
# 3    #302028   3919071        False   94.000000  34.000000   LeftFoot
# 4    #302028   3919071        False   94.000000  32.017501  RightFoot
# 5    #302028   3919071        False   78.768443  43.300128   LeftFoot
#
#      situation team_name
# 1   FromCorner   Udinese
# 2  RegularPlay     Milan
# 3      Penalty     Milan
# 4  RegularPlay     Milan
# 5  RegularPlay     Milan

# %%
df_raw.to_csv('../data/07-SerieA-ok.csv')

# %% [markdown]
# **Data Modeling**

# %%
# read data
df = pd.read_csv('../data/07-SerieA-ok.csv', index_col=0)
df.head()
# Out:
#    team_id  player_id     player_name  min  expected_goals    event_type
# 1     8600     844504   Rodrigo Becao    2        0.086003          Goal  \
# 2     8564     750027     Brahim Diaz    7        0.054140  AttemptSaved
# 3     8564     724371  Theo Hernández   11        0.788400          Goal
# 4     8564     265725      Ante Rebic   15        0.075055          Goal
# 5     8564     848844     Rafael Leao   18        0.033549          Miss
#
#   team_color  match_id  is_own_goal           x          y  shot_type
# 1    #907850   3919071        False  102.344825  39.545001     Header  \
# 2    #302028   3919071        False   95.350879  19.304968  RightFoot
# 3    #302028   3919071        False   94.000000  34.000000   LeftFoot
# 4    #302028   3919071        False   94.000000  32.017501  RightFoot
# 5    #302028   3919071        False   78.768443  43.300128   LeftFoot
#
#      situation team_name
# 1   FromCorner   Udinese
# 2  RegularPlay     Milan
# 3      Penalty     Milan
# 4  RegularPlay     Milan
# 5  RegularPlay     Milan

# %%
# shot locations (for bins)
pitch = VerticalPitch(pitch_type='uefa')
pitch.dim
# Out:
# FixedDims(pitch_width=68.0, pitch_length=105.0, goal_width=7.32, goal_length=2.0, six_yard_width=18.32, six_yard_length=5.5, penalty_area_width=40.32, penalty_area_length=16.5, circle_diameter=18.3, corner_diameter=2.0, arc=53.05, invert_y=False, origin_center=False, left=0.0, right=105.0, bottom=0.0, top=68.0, aspect=1.0, width=68.0, length=105.0, goal_bottom=30.34, goal_top=37.66, six_yard_left=5.5, six_yard_right=99.5, six_yard_bottom=24.84, six_yard_top=43.16, penalty_left=11.0, penalty_right=94.0, penalty_area_left=16.5, penalty_area_right=88.5, penalty_area_bottom=13.84, penalty_area_top=54.16, center_width=34.0, center_length=52.5, x_markings_sorted=array([  0. ,   5.5,  11. ,  16.5,  52.5,  88.5,  94. ,  99.5, 105. ]), y_markings_sorted=array([ 0.  , 13.84, 24.84, 30.34, 37.66, 43.16, 54.16, 68.  ]), pitch_extent=array([  0., 105.,   0.,  68.]), positional_x=array([  0. ,  16.5,  34.5,  52.5,  70.5,  88.5, 105. ]), positional_y=array([ 0.  , 13.84, 24.84, 43.16, 54.16, 68.  ]), stripe_locations=array([  0. ,   5.5,  11. ,  16.5,  22. ,  28.1,  34.2,  40.3,  46.4,
#         52.5,  58.6,  64.7,  70.8,  76.9,  83. ,  88.5,  94. ,  99.5,
#        105. ]), position_line4=PositionLine4(GK=Coordinate(x=11.0, y=34.0, x_flip=94.0, y_flip=34.0, x_half=2.75, y_half=34.0, x_half_flip=102.25, y_half_flip=34.0), RB=Coordinate(x=27.6, y=8.5, x_flip=77.4, y_flip=59.5, x_half=11.6, y_half=8.5, x_half_flip=93.4, y_half_flip=59.5), RCB=Coordinate(x=27.6, y=25.5, x_flip=77.4, y_flip=42.5, x_half=11.6, y_half=25.5, x_half_flip=93.4, y_half_flip=42.5), LCB=Coordinate(x=27.6, y=42.5, x_flip=77.4, y_flip=25.5, x_half=11.6, y_half=42.5, x_half_flip=93.4, y_half_flip=25.5), LB=Coordinate(x=27.6, y=59.5, x_flip=77.4, y_flip=8.5, x_half=11.6, y_half=59.5, x_half_flip=93.4, y_half_flip=8.5), RWB=Coordinate(x=44.2, y=8.5, x_flip=60.8, y_flip=59.5, x_half=20.45, y_half=8.5, x_half_flip=84.55, y_half_flip=59.5), RDM=Coordinate(x=44.2, y=25.5, x_flip=60.8, y_flip=42.5, x_half=20.45, y_half=25.5, x_half_flip=84.55, y_half_flip=42.5), LDM=Coordinate(x=44.2, y=42.5, x_flip=60.8, y_flip=25.5, x_half=20.45, y_half=42.5, x_half_flip=84.55, y_half_flip=25.5), LWB=Coordinate(x=44.2, y=59.5, x_flip=60.8, y_flip=8.5, x_half=20.45, y_half=59.5, x_half_flip=84.55, y_half_flip=8.5), RM=Coordinate(x=60.800000000000004, y=8.5, x_flip=44.199999999999996, y_flip=59.5, x_half=29.299999999999997, y_half=8.5, x_half_flip=75.7, y_half_flip=59.5), RCM=Coordinate(x=60.800000000000004, y=25.5, x_flip=44.199999999999996, y_flip=42.5, x_half=29.299999999999997, y_half=25.5, x_half_flip=75.7, y_half_flip=42.5), LCM=Coordinate(x=60.800000000000004, y=42.5, x_flip=44.199999999999996, y_flip=25.5, x_half=29.299999999999997, y_half=42.5, x_half_flip=75.7, y_half_flip=25.5), LM=Coordinate(x=60.800000000000004, y=59.5, x_flip=44.199999999999996, y_flip=8.5, x_half=29.299999999999997, y_half=59.5, x_half_flip=75.7, y_half_flip=8.5), RW=Coordinate(x=77.4, y=8.5, x_flip=27.599999999999994, y_flip=59.5, x_half=38.15, y_half=8.5, x_half_flip=66.85, y_half_flip=59.5), RAM=Coordinate(x=77.4, y=25.5, x_flip=27.599999999999994, y_flip=42.5, x_half=38.15, y_half=25.5, x_half_flip=66.85, y_half_flip=42.5), LAM=Coordinate(x=77.4, y=42.5, x_flip=27.599999999999994, y_flip=25.5, x_half=38.15, y_half=42.5, x_half_flip=66.85, y_half_flip=25.5), LW=Coordinate(x=77.4, y=59.5, x_flip=27.599999999999994, y_flip=8.5, x_half=38.15, y_half=59.5, x_half_flip=66.85, y_half_flip=8.5), RCF=Coordinate(x=94.0, y=25.5, x_flip=11.0, y_flip=42.5, x_half=47.0, y_half=25.5, x_half_flip=58.0, y_half_flip=42.5), LCF=Coordinate(x=94.0, y=42.5, x_flip=11.0, y_flip=25.5, x_half=47.0, y_half=42.5, x_half_flip=58.0, y_half_flip=25.5)), position_line5=PositionLine5(GK=Coordinate(x=11.0, y=34.0, x_flip=94.0, y_flip=34.0, x_half=2.75, y_half=34.0, x_half_flip=102.25, y_half_flip=34.0), RB=Coordinate(x=27.6, y=6.8, x_flip=77.4, y_flip=61.2, x_half=11.6, y_half=6.8, x_half_flip=93.4, y_half_flip=61.2), RCB=Coordinate(x=27.6, y=20.4, x_flip=77.4, y_flip=47.6, x_half=11.6, y_half=20.4, x_half_flip=93.4, y_half_flip=47.6), CB=Coordinate(x=27.6, y=34.0, x_flip=77.4, y_flip=34.0, x_half=11.6, y_half=34.0, x_half_flip=93.4, y_half_flip=34.0), LCB=Coordinate(x=27.6, y=47.6, x_flip=77.4, y_flip=20.4, x_half=11.6, y_half=47.6, x_half_flip=93.4, y_half_flip=20.4), LB=Coordinate(x=27.6, y=61.199999999999996, x_flip=77.4, y_flip=6.800000000000004, x_half=11.6, y_half=61.199999999999996, x_half_flip=93.4, y_half_flip=6.800000000000004), RWB=Coordinate(x=44.2, y=6.8, x_flip=60.8, y_flip=61.2, x_half=20.45, y_half=6.8, x_half_flip=84.55, y_half_flip=61.2), RDM=Coordinate(x=44.2, y=20.4, x_flip=60.8, y_flip=47.6, x_half=20.45, y_half=20.4, x_half_flip=84.55, y_half_flip=47.6), CDM=Coordinate(x=44.2, y=34.0, x_flip=60.8, y_flip=34.0, x_half=20.45, y_half=34.0, x_half_flip=84.55, y_half_flip=34.0), LDM=Coordinate(x=44.2, y=47.6, x_flip=60.8, y_flip=20.4, x_half=20.45, y_half=47.6, x_half_flip=84.55, y_half_flip=20.4), LWB=Coordinate(x=44.2, y=61.199999999999996, x_flip=60.8, y_flip=6.800000000000004, x_half=20.45, y_half=61.199999999999996, x_half_flip=84.55, y_half_flip=6.800000000000 ...

# %%
fig = plt.figure(figsize = (4,4), dpi = 100)
ax = plt.subplot(111)
pitch = VerticalPitch(
    pitch_type='uefa',
    half=True,
    axis=True, 
    label=True, 
    tick=True,
    goal_type='box'
)
pitch.draw(ax = ax)

ax.plot([13.84, 13.84], [ax.get_ylim()[0], ax.get_ylim()[1]], ls=':', color='red')
ax.plot([54.16, 54.16], [ax.get_ylim()[0], ax.get_ylim()[1]], ls=':', color='red')
ax.plot([24.84, 24.84], [ax.get_ylim()[0], ax.get_ylim()[1]], ls=':', color='red')
ax.plot([43.16, 43.16], [ax.get_ylim()[0], ax.get_ylim()[1]], ls=':', color='red')

ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [88.5,88.5], ls=':', color='red')
ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [99.5,99.5], ls=':', color='red')
ax.plot([ax.get_xlim()[0], ax.get_xlim()[1]], [75,75], ls=':', color='red')

# %%
# function that returns the zone based on the following criteria
zone_areas = {
    'zone_1':{
        'x_lower_bound': 54.16, 'x_upper_bound': 68,
        'y_lower_bound': 88.5, 'y_upper_bound': 105,
    },
    'zone_2':{
        'x_lower_bound': 0, 'x_upper_bound': 13.84,
        'y_lower_bound': 88.5, 'y_upper_bound': 105,
    },
    'zone_3':{
        'x_lower_bound': 54.16, 'x_upper_bound': 68,
        'y_lower_bound': 20, 'y_upper_bound': 88.5,
    },
    'zone_4':{
        'x_lower_bound': 0, 'x_upper_bound': 13.84,
        'y_lower_bound': 20, 'y_upper_bound': 88.5,
    },
    'zone_5':{
        'x_lower_bound': 13.84, 'x_upper_bound': 24.84,
        'y_lower_bound': 88.5, 'y_upper_bound': 105,
    },
    'zone_6':{
        'x_lower_bound': 43.16, 'x_upper_bound': 54.16,
        'y_lower_bound': 88.5, 'y_upper_bound': 105,
    },
    'zone_7':{
        'x_lower_bound': 24.84, 'x_upper_bound': 43.16,
        'y_lower_bound': 88.5, 'y_upper_bound': 99.5,
    },
    'zone_8':{
        'x_lower_bound': 24.84, 'x_upper_bound': 43.16,
        'y_lower_bound': 99.5, 'y_upper_bound': 105,
    },
    'zone_9':{
        'x_lower_bound': 13.84, 'x_upper_bound': 24.84,
        'y_lower_bound': 75, 'y_upper_bound': 88.5,
    },
    'zone_10':{
        'x_lower_bound': 43.16, 'x_upper_bound': 54.16,
        'y_lower_bound': 75, 'y_upper_bound': 88.5,
    },
    'zone_11':{
        'x_lower_bound': 24.84, 'x_upper_bound': 43.16,
        'y_lower_bound': 75, 'y_upper_bound': 88.5,
    },
    'zone_12':{
        'x_lower_bound': 13.84, 'x_upper_bound': 54.16,
        'y_lower_bound': 20, 'y_upper_bound': 75,
    }
}

# %%
def assign_shot_zone(x,y):
    '''
    This function returns the zone based on the x & y coordinates of the shot
    taken.
    Args:
        - x (float): the x position of the shot based on a vertical grid.
        - y (float): the y position of the shot based on a vertical grid.
    '''

    global zone_areas

    # Conditions

    for zone in zone_areas:
        if (x >= zone_areas[zone]['x_lower_bound']) & (x <= zone_areas[zone]['x_upper_bound']):
            if (y >= zone_areas[zone]['y_lower_bound']) & (y <= zone_areas[zone]['y_upper_bound']):
                return zone

# %%
fig = plt.figure(figsize = (4,4), dpi = 100)
ax = plt.subplot(111)
pitch = VerticalPitch(
    pitch_type='uefa',
    half=True,
    axis=True, 
    label=True, 
    tick=True,
    goal_type='box'
)
pitch.draw(ax = ax)

zone_colors = {
    'zone_1': 'black',
    'zone_2': 'red',
    'zone_3': 'blue',
    'zone_4': 'yellow',
    'zone_5': 'green',
    'zone_6': 'pink',
    'zone_7': 'purple',
    'zone_8': 'grey',
    'zone_9': 'brown',
    'zone_10': 'lightblue',
    'zone_11': 'lightcyan',
    'zone_12': 'lightgrey'
}

for zone in zone_colors:
    x_lim = [zone_areas[zone]['x_lower_bound'], zone_areas[zone]['x_upper_bound']]
    y1 = zone_areas[zone]['y_lower_bound']
    y2 = zone_areas[zone]['y_upper_bound']
    ax.fill_between(x=x_lim, y1=y1, y2=y2, color=zone_colors[zone])

# %% [markdown]
# Now we can assign the zone to each shot of our df, but remember that first we need to invert the x and y values, since we are using a vertical pitch.

# %%
df.rename(columns={'x':'y', 'y':'x'}, inplace=True)
df = df[df['situation'] != 'Penalty'].reset_index(drop=True)

# %%
df['zone_area'] = [assign_shot_zone(x,y) for x,y in zip(df['x'], df['y'])]
df
# Out:
#       team_id  player_id                 player_name  min  expected_goals
# 0        8600     844504               Rodrigo Becao    2        0.086003  \
# 1        8564     750027                 Brahim Diaz    7        0.054140
# 2        8564     265725                  Ante Rebic   15        0.075055
# 3        8564     848844                 Rafael Leao   18        0.033549
# 4        8600     534484               Isaac Success   20        0.030647
# ...       ...        ...                         ...  ...             ...
# 1822     8564    1131217               Pierre Kalulu   86        0.195098
# 1823     9875     773189             Tanguy Ndombélé   90        0.029205
# 1824     9875     612863  Andre-Frank Zambo Anguissa   90        0.030396
# 1825     8564     750027                 Brahim Diaz   90        0.104993
# 1826     8564    1131217               Pierre Kalulu   90        0.214541
#
#         event_type team_color  match_id  is_own_goal           y          x
# 0             Goal    #907850   3919071        False  102.344825  39.545001  \
# 1     AttemptSaved    #302028   3919071        False   95.350879  19.304968
# 2             Goal    #302028   3919071        False   94.000000  32.017501
# 3             Miss    #302028   3919071        False   78.768443  43.300128
# 4             Miss    #907850   3919071        False   98.535085  21.617071
# ...            ...        ...       ...          ...         ...        ...
# 1822          Post    #302028   3919457        False   98.631582  29.967858
# 1823  AttemptSaved    #003880   3919457        False   81.246118  33.313749
# 1824          Miss    #003880   3919457        False   79.331550  30.492501
# 1825  AttemptSaved    #302028   3919457        False   98.631582  37.768000
# 1826  AttemptSaved    #302028   3919457        False   99.879309  36.592501
#
#       shot_type        situation team_name zone_area
# 0        Header       FromCorner   Udinese    zone_8
# 1     RightFoot      RegularPlay     Milan    zone_5
# 2     RightFoot      RegularPlay     Milan    zone_7
# 3      LeftFoot      RegularPlay     Milan   zone_10
# 4     RightFoot  ThrowInSetPiece   Udinese    zone_5
# ...         ...              ...       ...       ...
# 1822  RightFoot      RegularPlay     Milan    zone_7
# 1823   LeftFoot      RegularPlay    Napoli   zone_11
# 1824  RightFoot       FromCorner    Napoli   zone_11
# 1825     Header      RegularPlay     Milan    zone_7
# 1826     Header       FromCorner     Milan    zone_8
#
# [1827 rows x 15 columns]

# %%
data = df.groupby(['team_id', 'team_name', 'team_color', 'zone_area']).apply(lambda x: x.shape[0]).reset_index()
data.rename(columns={0:'num_shots'}, inplace=True)

total_shots = data.groupby(['team_id'])['num_shots'].sum().reset_index()
total_shots.rename(columns={'num_shots':'total_shots'}, inplace=True)

data = pd.merge(data, total_shots, on='team_id', how='left')
data['pct_shots'] = data['num_shots']/data['total_shots']

# %%
data.head()
# Out:
#    team_id    team_name team_color zone_area  num_shots  total_shots
# 0     6480  Salernitana    #59181C   zone_10          3           92  \
# 1     6480  Salernitana    #59181C   zone_11         25           92
# 2     6480  Salernitana    #59181C   zone_12          3           92
# 3     6480  Salernitana    #59181C    zone_5          6           92
# 4     6480  Salernitana    #59181C    zone_6          4           92
#
#    pct_shots
# 0   0.032609
# 1   0.271739
# 2   0.032609
# 3   0.065217
# 4   0.043478

# %% [markdown]
# **Data Visualization**

# %%
def plot_shot_location(ax, fig, team_id, df=data):
    '''
    This functions plots the shot location grid for a team
    '''
    global zone_areas
    data = df.copy()

    pitch = VerticalPitch(
        pitch_type='uefa',
        half=True,
        goal_type='box',
        linewidth=1.25,
        line_color='black',
        spot_scale=0.0
    )
    pitch.draw(ax = ax)

    plot_df = data[data['team_id'] == team_id]
    max_value = plot_df['pct_shots'].max()
    team_name = plot_df['team_name'].iloc[0]
    team_color = plot_df['team_color'].iloc[0]
    team_id = plot_df['team_id'].iloc[0]
    total_shots = plot_df['total_shots'].iloc[0]

    # Grids
    ax.plot([13.84, 13.84], [40, 88.5], ls='--', color='black', lw=1)
    ax.plot([54.16, 54.16], [40, 88.5], ls='--', color='black', lw=1)
    ax.plot([24.84, 24.84], [99.5, 88.5], ls='--', color='black', lw=1)
    ax.plot([43.16, 43.16], [99.5, 88.5], ls='--', color='black', lw=1)

    ax.plot([68, 54.16], [88.5,88.5], ls='--', color='black', lw=1)
    ax.plot([0.5, 13.84], [88.5,88.5], ls='--', color='black', lw=1)
    ax.plot([13.84, 54.16], [75,75], ls='--', color='black', lw=1)

    for zone in plot_df['zone_area']:
        shot_pct = plot_df[plot_df['zone_area'] == zone]['pct_shots'].iloc[0]
        x_lim = [zone_areas[zone]['x_lower_bound'], zone_areas[zone]['x_upper_bound']]
        y1 = zone_areas[zone]['y_lower_bound']
        y2 = zone_areas[zone]['y_upper_bound']
        ax.fill_between(
            x=x_lim, 
            y1=y1, y2=y2, 
            color='#DA70D6', alpha=(shot_pct/max_value),
            zorder=0, ec='None')
        if shot_pct > 0.05:
            x_pos = x_lim[0] + abs(x_lim[0] - x_lim[1])/2
            if y1 == 20:
                y1 = 58
            y_pos = y1 + abs(y1 - y2)/2
            text_ = ax.annotate(
                xy=(x_pos, y_pos),
                text=f'{shot_pct:.0%}',
                ha='center',
                va='center',
                color='black',
                weight='bold',
                size=7
            )
            text_.set_path_effects(
                [path_effects.Stroke(linewidth=1.5, foreground='white'), path_effects.Normal()]
            )
    # -- Transformation functions
    ax.set_ylim(ax.get_ylim()[0], ax.get_ylim()[1])
    ax.set_xlim(ax.get_xlim()[0], ax.get_xlim()[1])
    DC_to_FC = ax.transData.transform
    FC_to_NFC = fig.transFigure.inverted().transform
    # -- Take data coordinates and transform them to normalized figure coordinates
    DC_to_NFC = lambda x: FC_to_NFC(DC_to_FC(x))
    ax_coords = DC_to_NFC((11,62.5))
    ax_size = 0.021
    image_ax = fig.add_axes(
        [ax_coords[0], ax_coords[1], ax_size, ax_size],
        fc='None', anchor='C'
    )
    fotmob_url = 'https://images.fotmob.com/image_resources/logo/teamlogo/'
    club_icon = Image.open(urllib.request.urlopen(f'{fotmob_url}{team_id:.0f}.png'))
    image_ax.imshow(club_icon)
    image_ax.axis('off')
    ax_text(
        x=67, y=120,
        s=f'{team_name} <| shots {total_shots:.0f}>',
        highlight_textprops=[{'size':8, 'weight':'normal'}],
        ax=ax,
        weight='bold',
        size=10
    )
    
    return ax

# %%
order_teams = total_shots.sort_values(by='total_shots', ascending=False)

# %%
layout_ = '''
    ABCD
    EFGH
    IJKL
    MNOP
    QRST
'''

height_ratios = [1]*5

fig = plt.figure(figsize=(10,12), dpi=300)
axs = fig.subplot_mosaic(
    layout_, 
    gridspec_kw={
        'height_ratios':height_ratios,
    }
)

counter = 0
for k, ax in axs.items():
    team_id = order_teams['team_id'].iloc[counter]
    plot_shot_location(ax, fig, team_id=team_id)
    counter += 1

fig_text(
    x = 0.12, y = .95, 
    s = "Serie A - Shooting Areas",
    va = "bottom", ha = "left",
    fontsize = 18, color = "black", weight = "bold"
)
fig_text(
	x = 0.12, y = .91, 
    s = "Percentage of <non-penalty shots> taken in each area.\nOnly areas with more than 5% of shots are labeled.",
    highlight_textprops=[{"weight": "bold", "color": "darkgrey"}],
	va = "bottom", ha = "left",
	fontsize = 12, color = "#4E616C"
)

fotmob_url_league = "https://images.fotmob.com/image_resources/logo/leaguelogo/"

# league logo
logo_ax = fig.add_axes([0.83, .92, 0.05, 0.05], zorder=1)
league_icon = Image.open(urllib.request.urlopen(f"{fotmob_url_league}55.png"))
logo_ax.imshow(league_icon)
logo_ax.axis("off")

plt.savefig(
	"../figures/07_SerieA_shots.png",
	dpi = 300,
	facecolor = "white",
	bbox_inches="tight",
    edgecolor="none",
	transparent = False
)

plt.savefig(
	"../figures/07_SerieA_shots_tr.png",
	dpi = 300,
	facecolor = "none",
	bbox_inches="tight",
    edgecolor="none",
	transparent = True
)
